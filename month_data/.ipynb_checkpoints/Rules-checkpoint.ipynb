# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from scipy import stats
import warnings
import sys
import seaborn as sns
sys.path.append('../')
pd.options.mode.chained_assignment = None

# %%
vdf = pd.read_csv("beeActivity.csv")
#vdf = vdf.drop_duplicates(subset=['track_starttime','track_tagid'], keep='last')

# %%
break_indexes = vdf.separate_event[vdf.separate_event == True].index.tolist()

# %%
#SECONDS THRESHOLD
#used to classify multiple detections into part of a single event
#also used to tell when two detections are part of different events
#by checking the time distance between them
t = 15

#DISTANCE THRESHOLD
#used to classify an event as entering or exiting
#when two consecutive detections of the same event 
#have this distance in y position, they are utilized to predict
#the trajectory. If not then it checks the detection prior for
#the distance threshold, and continues doing so until it finds
#the last detection in the event or until it finds a distance
#of more than the threshold

t2 = 150

#ANGLE THRESHOLD
#used to generate angle ranges for classifying as exiting
#or entering

angle = 10

# %%
vdf['event_id'] = np.nan
first_detection = 0
for i in range(len(break_indexes)):
        
        vdf['event_id'].iloc[first_detection:break_indexes[i]+1] = i
        first_detection = break_indexes[i]+1

# %% [markdown]
# ## RULES

# %%
#RULE 1 - INSIDE-OUTSIDE OR OUTSIDE-INSIDE
def in_out(data):
    if data['track_shape'].iloc[-1] == "inside_outside" or data['track_shape'].iloc[-1] == "ramp_outside":
        return "exiting"
    elif data['track_shape'].iloc[-1] == "outside_inside" or data['track_shape'].iloc[-1] == "outside_ramp":
        return "entering"
    else:
        return "unknown"
        

#RULE 2 ITERATE BACKWARDS DISPLACEMENT
def displacement(data):            
        coordinates = data['cy']
        
        final = coordinates.iloc[-1]
        
        for k in range(len(coordinates)):
            prev = coordinates.iloc[len(coordinates)-k-1]
            dif = final - prev
            if abs(dif) >= t2:
                if dif < 0:
                    return 'exiting'
                elif dif > 0:
                    return 'entering'
                else:
                    return 'unknown'
                break
            elif k == len(coordinates) - 1:
                if dif < 0:
                    return 'exiting'
                elif dif > 0:
                    return 'entering'
                else:
                    return 'unknown'
            

#RULE 3 SUMMED DIRECTIONAL ANGLE

def angles(data):
    exit_min = 180 + angle
    exit_max = 360 - angle
    enter_min = angle
    enter_max = 180 - angle

   
    coordinates = data['angle'].to_numpy()

    unit_dx = np.cos(np.deg2rad(coordinates))
    unit_dy = np.sin(np.deg2rad(coordinates))
    avg_x = np.average(unit_dx)
    avg_y = np.average(unit_dy)
    if avg_x == 0 and avg_y == 0:
        deg = 0
    elif avg_x == 0 and avg_y != 0:
        if avg_y > 0:
            deg = 270
        elif avg_y < 0:
            deg = 90
    else:
        # determine direction angle using arctan
        deg = np.rad2deg(np.arctan(avg_y/avg_x))
                    
        # since arctan limits are (-90,90), use coordinate directions to 
        # correct the angle to be within standard [0,360) range
        if avg_x > 0 and avg_y >= 0:
            deg = deg
        elif avg_x < 0 and avg_y >= 0:
            deg = 180 + deg
        elif avg_x < 0 and avg_y < 0:
            deg = deg + 180
        elif avg_x > 0 and avg_y < 0:
            deg = 360 + deg

    if deg >= exit_min and deg <= exit_max:
        return 'exiting'
    elif deg >= enter_min and deg <= enter_max:
        return 'entering'
    else:
        return 'unknown'

#RULE 4 LAST DIRECTIONAL ANGLE

def getangle(coordinates):
    exit_min = 180 + angle
    exit_max = 360 - angle
    enter_min = angle
    enter_max = 180 - angle

    avg_x = np.cos(np.deg2rad(coordinates))
    avg_y = np.sin(np.deg2rad(coordinates))
    if avg_x == 0 and avg_y == 0:
        deg = 0
    elif avg_x == 0 and avg_y != 0:
        if avg_y > 0:
            deg = 270
        elif avg_y < 0:
            deg = 90
    else:
        # determine direction angle using arctan
        deg = np.rad2deg(np.arctan(avg_y/avg_x))
                    
        # since arctan limits are (-90,90), use coordinate directions to 
        # correct the angle to be within standard [0,360) range
        if avg_x > 0 and avg_y >= 0:
            deg = deg
        elif avg_x < 0 and avg_y >= 0:
            deg = 180 + deg
        elif avg_x < 0 and avg_y < 0:
            deg = deg + 180
        elif avg_x > 0 and avg_y < 0:
            deg = 360 + deg

    if deg >= exit_min and deg <= exit_max:
        return 'exiting'
    elif deg >= enter_min and deg <= enter_max:
        return 'entering'
    else:
        return 'unknown'


def lastangle(data):
   
    coordinates = data['angle'].iloc[-1]

    return getangle(coordinates)


#RULE 5 INIT - FINAL DISPLACEMENT
def displacementinit(data):            
        coordinates = data['cy']
        
        final = coordinates.iloc[-1]
        init = coordinates.iloc[0]

        if init > final:
            return 'exiting'
        elif final > init:
            return 'entering'
        else:
            return 'unknown'             

#RULE 6 FIRST DIRECTIONAL ANGLE

def firstangle(data):
   
    coordinates = data['angle'].iloc[0]

    return getangle(coordinates)


#RULE 7 ITERATE FORWARDS DISPLACEMENT
def displacement2(data):            
        coordinates = data['cy']
        
        first = coordinates.iloc[0]
        
        for k in range(1,len(coordinates)):
            next = coordinates.iloc[k]
            dif = first - next
            if abs(dif) >= t2:
                if dif > 0:
                    return 'exiting'
                elif dif < 0:
                    return 'entering'
                else:
                    return 'unknown'
                break
            elif k == len(coordinates) - 1:
                if dif > 0:
                    return 'exiting'
                elif dif < 0:
                    return 'entering'
                else:
                    return 'unknown'
            


####CLASSIFICATION AS ENTERING-EXITING OR EXITING-ENTERING

#RULE 1 ITERATE BACKWARDS AND FORWARDS DISPLACEMENT
def displacementbackforth(data):   

        coordinates = data['cy']

        #ending movement
        final = coordinates.iloc[-1]
        
        for k in range(len(coordinates)):
            prev = coordinates.iloc[len(coordinates)-k-1]
            dif = final - prev
            if abs(dif) >= t2:
                if dif < 0:
                    string2 = 'exiting'
                elif dif > 0:
                    string2 = 'entering'
                else:
                    string2 = 'unknown'
                break
            elif k == len(coordinates) - 1:
                if dif < 0:
                    string2 = 'exiting'
                elif dif > 0:
                    string2 = 'entering'
                else:
                    string2 = 'unknown'

        #beginning movement
        #iterate forwards
        first = coordinates.iloc[0]
        
        for k in range(1,len(coordinates)):
            next = coordinates.iloc[k]
            dif = first - next
            if abs(dif) >= t2:
                if dif > 0:
                    string = 'exiting'
                elif dif < 0:
                    string = 'entering'
                else:
                    string = 'unknown'
                break
            elif k == len(coordinates) - 1:
                if dif > 0:
                    string = 'exiting'
                elif dif < 0:
                    string = 'entering'
                else:
                    string = 'unknown'

        return string if string == string2 else f"{string}-{string2}"
        

#RULE 2 FIRST AND LAST DIRECTIONAL ANGLE
    

def lastfirstangle(data):

    coordinates = data['angle'].iloc[-1]

    string2 = getangle(coordinates)

    coordinates = data['angle'].iloc[0]

    string = getangle(coordinates)

    return string if string == string2 else f"{string}-{string2}"

# %%
cheatsheet = pd.read_csv("cheatsheet.csv")

# %% [markdown]
# ## ACCURACY
#
# Accuracy tested on regular straightforward cases

# %%
functions = {
    'THRS_DOUBLE': in_out,
    'DISP_START_END': displacementinit,
    'DISP_START': displacement2,
    'DISP_END': displacement,
    'DISP_BIDIRECTIONAL':displacementbackforth,
    'BEE_ANGLE_SUM': angles,
    'BEE_ANGLE_START': firstangle,
    'BEE_ANGLE_END': lastangle,
    'BEE_ANGLE_BIDIRECTIONAL':lastfirstangle
}

accuracy = {r: 0 for r in functions}

for index, row in cheatsheet.iterrows():
    event = row['event']
    line = row['line']
    detections = vdf[vdf['event_id'] == line]

    for rule, func in functions.items():
        if func(detections) == event:
            accuracy[rule] += 1

# %%
results = {k: v/len(cheatsheet) for k, v in accuracy.items()}
results
# Out:
# {'THRS_DOUBLE': 0.91,
#  'DISP_START_END': 0.95,
#  'DISP_START': 0.95,
#  'DISP_END': 0.95,
#  'DISP_BIDIRECTIONAL': 0.91,
#  'BEE_ANGLE_SUM': 0.91,
#  'BEE_ANGLE_START': 0.84,
#  'BEE_ANGLE_END': 0.88,
#  'BEE_ANGLE_BIDIRECTIONAL': 0.72}

# %% [markdown]
# Accuracy tested on roundabout cases

# %%
cheatsheet2 = pd.read_csv("cheatsheetroundabout.csv")
functions = {
    'THRS_DOUBLE': in_out,
    'DISP_START_END': displacementinit,
    'DISP_START': displacement2,
    'DISP_END': displacement,
    'BEE_ANGLE_SUM': angles,
    'BEE_ANGLE_START': firstangle,
    'BEE_ANGLE_END': lastangle
}

accuracy = {r: 0 for r in functions}

for index, row in cheatsheet2.iterrows():
    event = row['event']
    line = row['line']
    detections = vdf[vdf['event_id'] == line]

    for rule, func in functions.items():
        if func(detections) == event:
            accuracy[rule] += 1

# %%
results = {k: v/len(cheatsheet2) for k, v in accuracy.items()}
results
# Out:
# {'THRS_DOUBLE': 0.11,
#  'DISP_START_END': 0.17,
#  'DISP_START': 0.04,
#  'DISP_END': 0.97,
#  'BEE_ANGLE_SUM': 0.17,
#  'BEE_ANGLE_START': 0.06,
#  'BEE_ANGLE_END': 0.75}

# %% [markdown]
# Cheatsheet with entering-leaving and leaving-entering

# %%
cheatsheet3 = pd.read_csv("cheatsheetboth.csv")
functions = {
    'DISP_BIDIRECTIONAL': displacementbackforth,
    'BEE_ANGLE_BIDIRECTIONAL': lastfirstangle,
}

accuracy = {r: 0 for r in functions}

for index, row in cheatsheet3.iterrows():
    event = row['event']
    line = row['line']
    detections = vdf[vdf['event_id'] == line]

    for rule, func in functions.items():
        if func(detections) == event:
            accuracy[rule] += 1

# %%
results = {k: v/len(cheatsheet3) for k, v in accuracy.items()}
results
# Out:
# {'DISP_BIDIRECTIONAL': 0.94, 'BEE_ANGLE_BIDIRECTIONAL': 0.62}

# %% [markdown]
# ## DIRECTIONAL COMPLEMENTARITY
#
# Tested on regular straightforward cases

# %%
rule_names = ['THRS_DOUBLE', 'DISP_START_END', 'DISP_START','DISP_END','DISP_BIDIRECTIONAL', 'BEE_ANGLE_SUM',
              'BEE_ANGLE_START','BEE_ANGLE_END','BEE_ANGLE_BIDIRECTIONAL']
complement = {rule: {rr: 0 for rr in rule_names} for rule in rule_names}
for index, row in cheatsheet.iterrows():
    event = row['event']
    line = row['line']
    detections = vdf[vdf['event_id'] == line]
    #rules
    rules = {
    'THRS_DOUBLE': in_out(detections),
    'DISP_START_END': displacementinit(detections),
    'DISP_START': displacement2(detections),
    'DISP_END': displacement(detections),
    'DISP_BIDIRECTIONAL':displacementbackforth(detections),
    'BEE_ANGLE_SUM': angles(detections),
    'BEE_ANGLE_START': firstangle(detections),
    'BEE_ANGLE_END': lastangle(detections),
    'BEE_ANGLE_BIDIRECTIONAL':lastfirstangle(detections)
    }

    for key, value in rules.items():
        if value == event:
            for otherrule, othervalue in rules.items():
                if otherrule != key and othervalue != value:
                    complement[key][otherrule] += 1

# %%
df = pd.DataFrame.from_dict(complement).transpose()/len(cheatsheet)
df
# Out:
#                          THRS_DOUBLE  DISP_START_END  DISP_START  DISP_END  \
# THRS_DOUBLE                     0.00            0.00        0.00      0.03
# DISP_START_END                  0.04            0.00        0.00      0.04
# DISP_START                      0.04            0.00        0.00      0.04
# DISP_END                        0.07            0.04        0.04      0.00
# DISP_BIDIRECTIONAL              0.03            0.00        0.00      0.00
# BEE_ANGLE_SUM                   0.02            0.00        0.00      0.03
# BEE_ANGLE_START                 0.02            0.00        0.00      0.04
# BEE_ANGLE_END                   0.08            0.05        0.05      0.03
# BEE_ANGLE_BIDIRECTIONAL         0.01            0.00        0.00      0.02
#
#                          DISP_BIDIRECTIONAL  BEE_ANGLE_SUM  BEE_ANGLE_START  \
# THRS_DOUBLE                            0.03           0.02             0.09
# DISP_START_END                         0.04           0.04             0.11
# DISP_START                             0.04           0.04             0.11
# DISP_END                               0.04           0.07             0.15
# DISP_BIDIRECTIONAL                     0.00           0.03             0.11
# BEE_ANGLE_SUM                          0.03           0.00             0.10
# BEE_ANGLE_START                        0.04           0.03             0.00
# BEE_ANGLE_END                          0.07           0.08             0.16
# BEE_ANGLE_BIDIRECTIONAL                0.02           0.02             0.00
#
#                          BEE_ANGLE_END  BEE_ANGLE_BIDIRECTIONAL
# THRS_DOUBLE                       0.11                     0.20
# DISP_START_END                    0.12                     0.23
# DISP_START                        0.12                     0.23
# DISP_END                          0.10                     0.25
# DISP_BIDIRECTIONAL                0.10                     0.21
# BEE_ANGLE_SUM                     0.11                     0.21
# BEE_ANGLE_START                   0.12                     0.12
# BEE_ANGLE_END                     0.00                     0.16
# BEE_ANGLE_BIDIRECTIONAL           0.00                     0.00

# %%
plot = sns.heatmap(df, annot=True)
fig = plot.get_figure()
fig.savefig("directionalcomplementarity1.png",bbox_inches='tight')

# %%
df2 = df + df.transpose()
df2
# Out:
#                          THRS_DOUBLE  DISP_START_END  DISP_START  DISP_END  \
# THRS_DOUBLE                     0.00            0.04        0.04      0.10
# DISP_START_END                  0.04            0.00        0.00      0.08
# DISP_START                      0.04            0.00        0.00      0.08
# DISP_END                        0.10            0.08        0.08      0.00
# DISP_BIDIRECTIONAL              0.06            0.04        0.04      0.04
# BEE_ANGLE_SUM                   0.04            0.04        0.04      0.10
# BEE_ANGLE_START                 0.11            0.11        0.11      0.19
# BEE_ANGLE_END                   0.19            0.17        0.17      0.13
# BEE_ANGLE_BIDIRECTIONAL         0.21            0.23        0.23      0.27
#
#                          DISP_BIDIRECTIONAL  BEE_ANGLE_SUM  BEE_ANGLE_START  \
# THRS_DOUBLE                            0.06           0.04             0.11
# DISP_START_END                         0.04           0.04             0.11
# DISP_START                             0.04           0.04             0.11
# DISP_END                               0.04           0.10             0.19
# DISP_BIDIRECTIONAL                     0.00           0.06             0.15
# BEE_ANGLE_SUM                          0.06           0.00             0.13
# BEE_ANGLE_START                        0.15           0.13             0.00
# BEE_ANGLE_END                          0.17           0.19             0.28
# BEE_ANGLE_BIDIRECTIONAL                0.23           0.23             0.12
#
#                          BEE_ANGLE_END  BEE_ANGLE_BIDIRECTIONAL
# THRS_DOUBLE                       0.19                     0.21
# DISP_START_END                    0.17                     0.23
# DISP_START                        0.17                     0.23
# DISP_END                          0.13                     0.27
# DISP_BIDIRECTIONAL                0.17                     0.23
# BEE_ANGLE_SUM                     0.19                     0.23
# BEE_ANGLE_START                   0.28                     0.12
# BEE_ANGLE_END                     0.00                     0.16
# BEE_ANGLE_BIDIRECTIONAL           0.16                     0.00

# %%
plot = sns.heatmap(df2, annot=True)
fig = plot.get_figure()
fig.savefig("symmetricalcomplementarity1.png",bbox_inches='tight')

# %% [markdown]
# Tested on roundabout cases

# %%
rule_names = ['THRS_DOUBLE', 'DISP_START_END', 'DISP_START','DISP_END', 'BEE_ANGLE_SUM',
              'BEE_ANGLE_START','BEE_ANGLE_END']
complement = {rule: {rr: 0 for rr in rule_names} for rule in rule_names}
for index, row in cheatsheet2.iterrows():
    event = row['event']
    line = row['line']
    detections = vdf[vdf['event_id'] == line]
    #rules
    rules = {
    'THRS_DOUBLE': in_out(detections),
    'DISP_START_END': displacementinit(detections),
    'DISP_START': displacement2(detections),
    'DISP_END': displacement(detections),
    'BEE_ANGLE_SUM': angles(detections),
    'BEE_ANGLE_START': firstangle(detections),
    'BEE_ANGLE_END': lastangle(detections)
    }

    for key, value in rules.items():
        if value == event:
            for otherrule, othervalue in rules.items():
                if otherrule != key and othervalue != value:
                    complement[key][otherrule] += 1

# %%
df = pd.DataFrame.from_dict(complement).transpose()/len(cheatsheet2)
df
# Out:
#                  THRS_DOUBLE  DISP_START_END  DISP_START  DISP_END  \
# THRS_DOUBLE             0.00            0.08        0.10      0.00
# DISP_START_END          0.14            0.00        0.13      0.00
# DISP_START              0.03            0.00        0.00      0.00
# DISP_END                0.86            0.80        0.93      0.00
# BEE_ANGLE_SUM           0.10            0.13        0.16      0.01
# BEE_ANGLE_START         0.05            0.03        0.05      0.00
# BEE_ANGLE_END           0.69            0.66        0.74      0.01
#
#                  BEE_ANGLE_SUM  BEE_ANGLE_START  BEE_ANGLE_END
# THRS_DOUBLE               0.04             0.10           0.05
# DISP_START_END            0.13             0.14           0.08
# DISP_START                0.03             0.03           0.03
# DISP_END                  0.81             0.91           0.23
# BEE_ANGLE_SUM             0.00             0.15           0.03
# BEE_ANGLE_START           0.04             0.00           0.03
# BEE_ANGLE_END             0.61             0.72           0.00

# %%
plot = sns.heatmap(df, annot=True)
fig = plot.get_figure()
fig.savefig("directionalcomplementarity2.png",bbox_inches='tight')

# %%
df2 = df + df.transpose()
df2
# Out:
#                  THRS_DOUBLE  DISP_START_END  DISP_START  DISP_END  \
# THRS_DOUBLE             0.00            0.22        0.13      0.86
# DISP_START_END          0.22            0.00        0.13      0.80
# DISP_START              0.13            0.13        0.00      0.93
# DISP_END                0.86            0.80        0.93      0.00
# BEE_ANGLE_SUM           0.14            0.26        0.19      0.82
# BEE_ANGLE_START         0.15            0.17        0.08      0.91
# BEE_ANGLE_END           0.74            0.74        0.77      0.24
#
#                  BEE_ANGLE_SUM  BEE_ANGLE_START  BEE_ANGLE_END
# THRS_DOUBLE               0.14             0.15           0.74
# DISP_START_END            0.26             0.17           0.74
# DISP_START                0.19             0.08           0.77
# DISP_END                  0.82             0.91           0.24
# BEE_ANGLE_SUM             0.00             0.19           0.64
# BEE_ANGLE_START           0.19             0.00           0.75
# BEE_ANGLE_END             0.64             0.75           0.00

# %%
plot = sns.heatmap(df2, annot=True)
fig = plot.get_figure()
fig.savefig("symmetricalcomplementarity2.png",bbox_inches='tight')

# %% [markdown]
# Cheatsheet with entering-leaving and leaving-entering

# %%
rule_names = ['DISP_BIDIRECTIONAL','BEE_ANGLE_BIDIRECTIONAL']
complement = {rule: {rr: 0 for rr in rule_names} for rule in rule_names}
for index, row in cheatsheet3.iterrows():
    event = row['event']
    line = row['line']
    detections = vdf[vdf['event_id'] == line]
    #rules
    rules = {
    'DISP_BIDIRECTIONAL':displacementbackforth(detections),
    'BEE_ANGLE_BIDIRECTIONAL':lastfirstangle(detections)
    }

    for key, value in rules.items():
        if value == event:
            for otherrule, othervalue in rules.items():
                if otherrule != key and othervalue != value:
                    complement[key][otherrule] += 1

# %%
df = pd.DataFrame.from_dict(complement)/len(cheatsheet2)
df
# Out:
#                          DISP_BIDIRECTIONAL  BEE_ANGLE_BIDIRECTIONAL
# DISP_BIDIRECTIONAL                     0.00                      0.0
# BEE_ANGLE_BIDIRECTIONAL                0.32                      0.0

# %%
plot = sns.heatmap(df, annot=True)
fig = plot.get_figure()
fig.savefig("directionalcomplementarity3.png",bbox_inches='tight')

# %%
df2 = df + df.transpose()
df2
# Out:
#                          DISP_BIDIRECTIONAL  BEE_ANGLE_BIDIRECTIONAL
# DISP_BIDIRECTIONAL                     0.00                     0.32
# BEE_ANGLE_BIDIRECTIONAL                0.32                     0.00

# %%
plot = sns.heatmap(df2, annot=True)
fig = plot.get_figure()
fig.savefig("symmetricalcomplementarity3.png",bbox_inches='tight')
